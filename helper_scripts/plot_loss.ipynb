# %%
import plotly.graph_objects as go
import numpy as np

r = [400, 440]

no_anomalies = open('/Users/haraldott/Downloads/results/Transfer Sasho Utah/bert_epochs_100_seq_len_7_description__no_anomaly/anomaly_loss_values', 'r')
no_anomalies_values = [float(y) for y in no_anomalies.readlines()]

fig = go.Figure(data=go.Scatter(y=no_anomalies_values))
fig.update_xaxes(range=[10, 60])
fig.update_yaxes(range=[0, 0.1])
fig.show()

#################################################

anomaly = open('/Users/haraldott/Downloads/results/Transfer Sasho Utah/bert_epochs_100_seq_len:_7_anomaly_type:insert_words_1/anomaly_loss_values', 'r')
log_containing_anomalies = [float(y) for y in anomaly.readlines()]

fig2 = go.Figure(data=go.Scatter(y=log_containing_anomalies))
fig2.update_xaxes(range=[10, 60])
fig2.update_yaxes(range=[0, 0.1])
fig2.show()
# Out:
# <div>
#
#
#             <div id="a5e87ae1-f72c-4024-85e1-cf120a03f491" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("a5e87ae1-f72c-4024-85e1-cf120a03f491")) {
#                     Plotly.newPlot(
#                         'a5e87ae1-f72c-4024-85e1-cf120a03f491',
# ...
